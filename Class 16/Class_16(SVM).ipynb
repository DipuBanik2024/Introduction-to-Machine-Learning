# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2d66e9af-d5e8-4e63-8701-68907b516a3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d66e9af-d5e8-4e63-8701-68907b516a3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('svm data.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  feature1  feature2  label_y
# 0           0  8.660254  -5.00000        0
# 1           1  8.717792  -4.89899        0
# 2           2  8.773790  -4.79798        0
# 3           3  8.828277  -4.69697        0
# 4           4  8.881281  -4.59596        0

# %%
df.shape
# Out:
# (400, 4)

# %%
df.drop('Unnamed: 0', inplace=True, axis=1)

# %%
df.head()
# Out:
#    feature1  feature2  label_y
# 0  8.660254  -5.00000        0
# 1  8.717792  -4.89899        0
# 2  8.773790  -4.79798        0
# 3  8.828277  -4.69697        0
# 4  8.881281  -4.59596        0

# %%
plt.scatter(df['feature1'],df['feature2'])

# %%
df1 = df[df['label_y']==0]
df2 = df[df['label_y']==1]

# %%
df1.head()
# Out:
#    feature1  feature2  label_y
# 0  8.660254  -5.00000        0
# 1  8.717792  -4.89899        0
# 2  8.773790  -4.79798        0
# 3  8.828277  -4.69697        0
# 4  8.881281  -4.59596        0

# %%
df2.head()
# Out:
#      feature1  feature2  label_y
# 200  0.000000  -5.00000        1
# 201  0.999949  -4.89899        1
# 202  1.406908  -4.79798        1
# 203  1.714198  -4.69697        1
# 204  1.969049  -4.59596        1

# %%
df1.shape
# Out:
# (200, 3)

# %%
df2.shape
# Out:
# (200, 3)

# %%
plt.scatter(df1.feature1,df1.feature2,color='red',label='NO')

# %%
plt.scatter(df2.feature1,df2.feature2,color='green',label='YES')

# %%
plt.scatter(df1.feature1,df1.feature2,color='red',label='NO')
plt.scatter(df2.feature1,df2.feature2,color='green',label='YES')
plt.legend()

# %%
from sklearn.model_selection import train_test_split as tts

# %%
xtrain,xtest,ytrain,ytest = tts(df.drop('label_y',axis=1),df['label_y'],test_size=0.3,random_state=88)

# %%
xtrain.head()
# Out:
#      feature1  feature2
# 244  4.969040 -0.555556
# 133 -9.860133  1.666667
# 68   9.823849  1.868687
# 70   9.783260  2.070707
# 42   9.971263 -0.757576

# %%
from sklearn.svm import SVC #support vector classifier
from sklearn.svm import SVR #support vector Regression

# %%
svm1 = SVC(kernel='linear')

# %%
svm1.fit(xtrain,ytrain)
# Out:
# SVC(kernel='linear')

# %%
svm1.score(xtest,ytest)
# Out:
# 0.49166666666666664

# %%
svm2 = SVC(kernel='rbf')

# %%
svm2.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
svm2.score(xtest,ytest)
# Out:
# 1.0

# %%
df.shape
# Out:
# (400, 3)

# %%
df['f1f2'] = (df.feature1)*(df.feature2)
df['f1f1'] = (df.feature1)*(df.feature1)
df['f2f2'] = (df.feature2)*(df.feature2)

# %%
df.shape
# Out:
# (400, 6)

# %%
df.head()
# Out:
#    feature1  feature2  label_y       f1f2       f1f1       f2f2
# 0  8.660254  -5.00000        0 -43.301270  75.000000  25.000000
# 1  8.717792  -4.89899        0 -42.708375  75.999898  24.000102
# 2  8.773790  -4.79798        0 -42.096467  76.979390  23.020610
# 3  8.828277  -4.69697        0 -41.466150  77.938476  22.061524
# 4  8.881281  -4.59596        0 -40.818009  78.877155  21.122845

# %%
df.drop('label_y',axis=1,inplace=True)

# %%
import plotly.express as px

# %%
px.scatter_3d(df,x='f1f2',y='f1f1',z='f2f2')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
